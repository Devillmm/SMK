# %%
## Read .CSV Files from Local Directory using "Pandas Read CSV"
# pd.read_csv("FilePath")

# Import & Upload Files
from google.colab import files
uploaded = files.upload()

# Import Pandas
import pandas as pd

# Read .CSV File
df_csv = pd.read_csv("customers.csv")

# Print 'first 5 Records' & 'last 5 Records'
print(df_csv)

# %%
# Print First 5 Records
# df.head()

print(df_csv.head())

# %%
# Print Last 5 Records
# df.tail()

print(df_csv.tail())

# %%
# Print First 3 Records using df.head()
print(df_csv.head(3))

# %%
# Print Last 3 Records using df.tail()
print(df_csv.tail(3))

# %%
# Print All Records in a Single Sheet
# df.to_string()

print(df_csv.to_string())
