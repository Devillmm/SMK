# %%
## Read .JSON Files from Local Directory using "Pandas Read Json"
# pd.read_json("FilePath")

# Import & Upload Files
from google.colab import files
uploaded = files.upload()

# Import Pandas
import pandas as pd

# Read .JSON File
df_json = pd.read_json("colors.json")

# Print 'First 5 Records' & 'Last 5 Records'
print(df_json)
# Out:
#      <input type="file" id="files-908ba579-37a2-4fc1-ade0-57cf7b482b27" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-908ba579-37a2-4fc1-ade0-57cf7b482b27">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Print First 5 Records - df.head()
print(df_json.head())

# %%
# Print Last 5 Records - df.tail()
print(df_json.tail())

# %%
# Print All Records in a Single Sheet - df.to_string()
print(df_json.to_string())
# Out:
#                                                                                                  colors
# 0           {'name': 'Black', 'hex': '#000000', 'rgb': {'r': 0, 'g': 0, 'b': 0}, 'category': 'neutral'}
# 1     {'name': 'White', 'hex': '#FFFFFF', 'rgb': {'r': 255, 'g': 255, 'b': 255}, 'category': 'neutral'}
# 2           {'name': 'Red', 'hex': '#FF0000', 'rgb': {'r': 255, 'g': 0, 'b': 0}, 'category': 'primary'}
# 3         {'name': 'Green', 'hex': '#00FF00', 'rgb': {'r': 0, 'g': 255, 'b': 0}, 'category': 'primary'}
# 4          {'name': 'Blue', 'hex': '#0000FF', 'rgb': {'r': 0, 'g': 0, 'b': 255}, 'category': 'primary'}
# 5    {'name': 'Yellow', 'hex': '#FFFF00', 'rgb': {'r': 255, 'g': 255, 'b': 0}, 'category': 'secondary'}
# 6      {'name': 'Cyan', 'hex': '#00FFFF', 'rgb': {'r': 0, 'g': 255, 'b': 255}, 'category': 'secondary'}
# 7   {'name': 'Magenta', 'hex': '#FF00FF', 'rgb': {'r': 255, 'g': 0, 'b': 255}, 'category': 'secondary'}
# ...
