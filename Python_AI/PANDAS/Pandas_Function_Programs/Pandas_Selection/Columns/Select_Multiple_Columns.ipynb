# %%
# Select Multiple Columns
# Import & Upload Files
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-748a7115-b65b-4227-a746-497e407d40bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-748a7115-b65b-4227-a746-497e407d40bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import Pandas
import pandas as pd

# Read the .CSV File
df = pd.read_csv("leads.csv")

# Print First & Last 5 Records of .CSV File
print(df)
# Out:
#     Index       Account Id     Lead Owner First Name Last Name  \
# 0       1  15a39d5cDE6CBb6    Bill Butler     Melvin    Orozco
# 1       2  B5ABd4CEbfdeb00    Cole Austin      Tommy     Russo
# 2       3  D97FA45A0a7Fdb2     Tim Rogers     Sophia   Wiggins
# 3       4  A039bE54aEFDbEF     Gail Reyes     Debbie   Wiggins
# 4       5  fAFF4D8ea4Dd942     Kim Gibson    Leonard   Hampton
# ..    ...              ...            ...        ...       ...
# 95     96  DcE55d8035dC6be    Vernon Kirk     Kelsey      Ball
# 96     97  A1Ab10C1CdEE1D6      Max Small    Rachael    Horton
# 97     98  5A09E70B1561Bed   Kara Hammond      Lacey   Schmitt
# 98     99  CA78BB0b87B7FAe  Kelsey Briggs   Lorraine     Lucas
# 99    100  e0feC0D7E42cf32  Manuel Rivers     Janice      Chen
#
#                  Company                 Phone 1                Phone 2  \
# 0   Peck, Olsen and Cobb        498-650-7488x407       001-088-191-4759
# ...

# %%
# Print First & Last 5 Records by Multiple Columns
# df[["column_1","column_2","column_3",...]]
print(df[["Account Id","Lead Owner","Company"]])
# Out:
#          Account Id     Lead Owner               Company
# 0   15a39d5cDE6CBb6    Bill Butler  Peck, Olsen and Cobb
# 1   B5ABd4CEbfdeb00    Cole Austin         Murphy-Walter
# 2   D97FA45A0a7Fdb2     Tim Rogers       Kelley-Garrison
# 3   A039bE54aEFDbEF     Gail Reyes       Figueroa-Galvan
# 4   fAFF4D8ea4Dd942     Kim Gibson        Steele-Shepard
# ..              ...            ...                   ...
# 95  DcE55d8035dC6be    Vernon Kirk             Stark LLC
# 96  A1Ab10C1CdEE1D6      Max Small              Le-Woods
# 97  5A09E70B1561Bed   Kara Hammond         Camacho-Hicks
# 98  CA78BB0b87B7FAe  Kelsey Briggs            Durham Ltd
# 99  e0feC0D7E42cf32  Manuel Rivers         Weber-Schmidt
#
# [100 rows x 3 columns]

# %%
# Print First 6 Records by Multiple Columns
# df.head()
print(df[["Account Id","Lead Owner","Company"]].head(6))
# Out:
#         Account Id     Lead Owner               Company
# 0  15a39d5cDE6CBb6    Bill Butler  Peck, Olsen and Cobb
# 1  B5ABd4CEbfdeb00    Cole Austin         Murphy-Walter
# 2  D97FA45A0a7Fdb2     Tim Rogers       Kelley-Garrison
# 3  A039bE54aEFDbEF     Gail Reyes       Figueroa-Galvan
# 4  fAFF4D8ea4Dd942     Kim Gibson        Steele-Shepard
# 5  7C98b7d0Fc406Ec  Roberta Perez         Christian Inc

# %%
# Print Last 5 Records by Multiple Columns
# df.tail()
print(df[["Account Id","Lead Owner","Company"]].tail())
# Out:
#          Account Id     Lead Owner        Company
# 95  DcE55d8035dC6be    Vernon Kirk      Stark LLC
# 96  A1Ab10C1CdEE1D6      Max Small       Le-Woods
# 97  5A09E70B1561Bed   Kara Hammond  Camacho-Hicks
# 98  CA78BB0b87B7FAe  Kelsey Briggs     Durham Ltd
# 99  e0feC0D7E42cf32  Manuel Rivers  Weber-Schmidt

# %%
# Print All Records in a Single Sheet by Multiple Columns
# df.to_string()
print(df[["Account Id","Lead Owner","Company"]].to_string())
# Out:
#          Account Id           Lead Owner                           Company
# 0   15a39d5cDE6CBb6          Bill Butler              Peck, Olsen and Cobb
# 1   B5ABd4CEbfdeb00          Cole Austin                     Murphy-Walter
# 2   D97FA45A0a7Fdb2           Tim Rogers                   Kelley-Garrison
# 3   A039bE54aEFDbEF           Gail Reyes                   Figueroa-Galvan
# 4   fAFF4D8ea4Dd942           Kim Gibson                    Steele-Shepard
# 5   7C98b7d0Fc406Ec        Roberta Perez                     Christian Inc
# 6   A3Ba161Db2aDF87          Sherry Rich          Jackson, Hull and Murphy
# 7   f4D4e518F0C16bf           Jeff Nunez                   Norton and Sons
# 8   AEcC0aE614eeDE4          Ray Allison         Yates, Santana and Holder
# 9   d9DC7cECc95A2De    Caroline Cantrell                     Moody-Webster
# 10  D16F0B9Ea101ab9      Matthew Fuentes                       Barry-Duffy
# ...
