# %%
# Select Specific Columns
# Import & Upload Files
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7287f629-bbda-419c-b20a-c6fd14ea9296" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7287f629-bbda-419c-b20a-c6fd14ea9296">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import Pandas
import pandas as pd

# Read the .CSV File
df = pd.read_csv("customers.csv")

# Print the first & Last 5 records
print(df)

# %%
# Print "First Name" Column - Specific Column
print(df["First Name"])

# It Prints First & Last 5 Records of the "First Name" Column
# Out:
# 0       Sheryl
# 1      Preston
# 2          Roy
# 3        Linda
# 4       Joanna
#         ...
# 95        Karl
# 96        Lynn
# 97        Fred
# 98      Yvonne
# 99    Clarence
# Name: First Name, Length: 100, dtype: object

# %%
# Print "First Name" Column with First 5 Records
print(df["First Name"].head())
# Out:
# 0     Sheryl
# 1    Preston
# 2        Roy
# 3      Linda
# 4     Joanna
# Name: First Name, dtype: object

# %%
# Print "First Name" Column with Last 5 Records
print(df["First Name"].tail())
# Out:
# 95        Karl
# 96        Lynn
# 97        Fred
# 98      Yvonne
# 99    Clarence
# Name: First Name, dtype: object

# %%
# Print "First Name" Column with All Records in a Single Sheet
print(df["First Name"].to_string())
# Out:
# 0         Sheryl
# 1        Preston
# 2            Roy
# 3          Linda
# 4         Joanna
# 5          Aimee
# 6         Darren
# 7          Brett
# 8         Sheryl
# 9       Michelle
# 10          Carl
# 11         Jenna
# 12        Tracey
# 13      Kristine
# 14         Faith
# 15       Miranda
# 16      Caroline
# 17          Greg
# 18      Clifford
# 19        Joanna
# 20       Maxwell
# 21         Kiara
# 22       Colleen
# 23         Janet
# 24         Shane
# 25        Marcus
# 26        Dakota
# 27     Frederick
# 28      Stefanie
# 29          Kent
# 30          Jack
# 31           Tom
# 32       Gabriel
# 33       Kaitlyn
# 34         Faith
# 35        Tammie
# 36      Nicholas
# 37        Jordan
# 38         Bruce
# 39        Sherry
# 40       Natalie
# 41         Bryan
# 42         Wayne
# 43          Luis
# 44        Rhonda
# 45        Joanne
# 46      Geoffrey
# 47        Gloria
# 48         Brady
# 49        Latoya
# 50        Gerald
# 51        Samuel
# ...
